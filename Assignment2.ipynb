# %% [markdown]
# <a href="https://colab.research.google.com/github/welmi496/Assignment2-WW/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## GitHub Setup
# 1. Create a GitHub account if you do not already have one.
# 2. Create a Personal Access Token (PAT) with the required permissions.
# 3. Insert screenshots in your PDF report for:
#    - GitHub account created/logged in
#    - PAT created successfully

# %%
# Configure Git in Colab

# !git config --global user.name "welmi496/Introduction-to-Artificial-Intelligence"
# !git config --global user.email "welmi496@gmail.com"

# Confirm Git configuration
# !git config --global user.name
# !git config --global user.email
# Out:
# welmi496/Introduction-to-Artificial-Intelligence
# welmi496@gmail.com

# %% [markdown]
# ## Repository Setup

# %%
# Create a folder for my work and move into it
import os

repo_name = "assignment2-WW"
os.makedirs("/content/workspace", exist_ok=True)
# %cd /content/workspace
# Out:
# /content/workspace

# %%
# Clone my public GitHub repository

# !git clone https://github.com/welmi496/Assignment2-WW.git
# %cd /content/workspace/assignment2-WW

# Confirm the repository contents
# !ls -la
# Out:
# fatal: destination path 'Assignment2-WW' already exists and is not an empty directory.
# [Errno 2] No such file or directory: '/content/workspace/assignment2-WW'
# /content/workspace/Assignment2-WW
# total 28
# drwxr-xr-x 4 root root 4096 Apr 11 03:02 .
# drwxr-xr-x 3 root root 4096 Apr 11 01:30 ..
# -rw-r--r-- 1 root root 5680 Apr 11 01:30 Assignment2.ipynb
# drwxr-xr-x 3 root root 4096 Apr 11 03:02 Assignment2-WW
# drwxr-xr-x 8 root root 4096 Apr 11 03:02 .git
# -rw-r--r-- 1 root root   16 Apr 11 01:30 README.md

# %% [markdown]
# ## Notebook Content

# %%
def multiply_numbers(a, b):
    return a * b

print(multiply_numbers(3, 4))
# Out:
# 12

# %% [markdown]
# ## Version Control Commands

# %%
# Save this notebook in the repository as assignment2.ipynb before running these commands

# !git add Assignment2.ipynb
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# On branch feature-branch
# Your branch is up to date with 'origin/feature-branch'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Assignment2-WW/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ## Branching and Updates

# %%
# !git checkout -b feature-branch
# Out:
# fatal: A branch named 'feature-branch' already exists.

# %%
def divide_numbers(a, b):
    if b != 0:
        return a / b
    else:
        return "Cannot divide by zero"

print(divide_numbers(10, 2))
# Out:
# 5.0

# %%
# !git add Assignment2.ipynb
# !git commit -m "Add division function"
# !git push --set-upstream origin feature-branch
# Out:
# On branch feature-branch
# Your branch is up to date with 'origin/feature-branch'.
#
# nothing to commit, working tree clean
# Branch 'feature-branch' set up to track remote branch 'feature-branch' from 'origin'.
# Everything up-to-date

# %% [markdown]
# ## Public Links
#
# Replace the placeholders below with your real links before submission.
#
# - Colab notebook link: https://colab.research.google.com/drive/1e0tiVqixOuq_BR8hjT36MIwlnBwVA5J8?usp=sharing
# - GitHub repository link: https://github.com/welmi496/Assignment2-WW/blob/main/Assignment2.ipynb`
